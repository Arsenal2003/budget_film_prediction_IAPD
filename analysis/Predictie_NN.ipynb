# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/content/movies_cleaned_final.csv')

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#                         Title  Rating Runtime          Directors  \
# 0       Închisoarea îngerilor     9.3  2h 22m     Frank Darabont
# 1             Cavalerul negru     9.1  2h 32m  Christopher Nolan
# 2                   Începutul     8.8  2h 28m  Christopher Nolan
# 3  Fight Club - Sala de lupte     8.8  2h 19m      David Fincher
# 4                Pulp Fiction     8.8  2h 34m  Quentin Tarantino
#
#                                              Writers  \
# 0                       Stephen King, Frank Darabont
# 1  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 2                                  Christopher Nolan
# 3                          Chuck Palahniuk, Jim Uhls
# 4                     Quentin Tarantino, Roger Avary
#
#                                                Stars  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 3  Edward Norton, Brad Pitt, Meat Loaf, Zach Gren...
# 4  Tim Roth, Amanda Plummer, Laura Lovelace, John...
#
#                                               Genres  Popularity       Budget  \
# 0            Epic, Period Drama, Prison Drama, Drama        55.0   25000000.0
# 1  Action Epic, Epic, Psychological Drama, Psycho...        92.0  185000000.0
# 2  Action Epic, Adventure Epic, Epic, Psychologic...        84.0  160000000.0
# 3  Dark Comedy, Psychological Drama, Psychologica...       148.0   63000000.0
# 4    Dark Comedy, Drug Crime, Gangster, Crime, Drama       141.0    8000000.0
#
#    Gross Worldwide                                    URL
# 0     2.933403e+07  https://www.imdb.com/title/tt0111161/
# 1     1.009243e+09  https://www.imdb.com/title/tt0468569/
# 2     8.397865e+08  https://www.imdb.com/title/tt1375666/
# 3     1.013210e+08  https://www.imdb.com/title/tt0137523/
# 4     2.139288e+08  https://www.imdb.com/title/tt0110912/

# %%
import re

def convert_runtime_to_minutes(runtime_str):
    if pd.isna(runtime_str): # Handle NaN values
        return None

    # Initialize hours and minutes
    total_minutes = 0

    # Extract hours (e.g., '2h')
    hours_match = re.search(r'(\d+)h', runtime_str)
    if hours_match:
        total_minutes += int(hours_match.group(1)) * 60

    # Extract minutes (e.g., '22m')
    minutes_match = re.search(r'(\d+)m', runtime_str)
    if minutes_match:
        total_minutes += int(minutes_match.group(1))

    return total_minutes

# Apply the conversion function to create the new column
df['Runtime (minutes)'] = df['Runtime'].apply(convert_runtime_to_minutes)

# Display the first 5 rows with the new column
display(df[['Title', 'Runtime', 'Runtime (minutes)']].sample(n=5))
# Out:
#                                 Title Runtime  Runtime (minutes)
# 3008             Yeopgijeogin geunyeo  2h 17m                137
# 6262                        Foul Play  1h 56m                116
# 3123                         Scanners  1h 43m                103
# 361   Scott Pilgrim împotriva tuturor  1h 52m                112
# 4459               Ultimul radio show  1h 45m                105

# %%
df['ROI'] = df['Gross Worldwide'] / df['Budget']

# Display a sample of the DataFrame with the new 'ROI' column
display(df[['Title', 'Budget', 'Gross Worldwide', 'ROI']].sample(n=5))
# Out:
#                                Title      Budget  Gross Worldwide       ROI
# 3321  Tae Guk Gi - Frăția războiului  12800000.0       81407286.0  6.359944
# 6602                          Munje!  20000000.0           1833.0  0.000092
# 8721                  Soul Survivors  17000000.0        4299141.0  0.252891
# 122               O fată de milioane  30000000.0      216763646.0  7.225455
# 3366                       Jucaria 2  13000000.0       35763605.0  2.751047

# %%
# Initialize an empty list to store all individual directors
all_directors = []

# Iterate through the 'Directors' column
for directors_list in df['Directors']:
    if pd.isna(directors_list):
        continue
    # Split the string by comma and strip whitespace from each name
    directors = [d.strip() for d in directors_list.split(',')]
    all_directors.extend(directors)

# Create a pandas Series from the list of all directors and count their frequencies
director_frequency = pd.Series(all_directors).value_counts().reset_index()
director_frequency.columns = ['Director', 'Frequency']

# Display the new DataFrame with director frequencies
display(director_frequency)
display(director_frequency["Director"].size)
# director_frequency.to_csv('director_frequency.csv', index=False)
# Out:
#                         Director  Frequency
# 0                    Woody Allen         47
# 1               Alfred Hitchcock         38
# 2                 Clint Eastwood         34
# 3               Steven Spielberg         29
# 4                Martin Scorsese         24
# ...                          ...        ...
# 4234  Alexandre de La Patellière          1
# 4235          Stéphane Foenkinos          1
# 4236             David Foenkinos          1
# 4237                Andrew Sipes          1
# 4238              George Ratliff          1
#
# [4239 rows x 2 columns]
# 4239

# %%
director_freq_dict = director_frequency.set_index('Director')['Frequency'].to_dict()

def calculate_directors_freq(directors_str):
    if pd.isna(directors_str):
        return None

    individual_directors = [d.strip() for d in directors_str.split(',')]
    total_frequency = 0

    for director in individual_directors:
        total_frequency += director_freq_dict.get(director, 0) # Get frequency, default to 0 if not found

    # Calculate the average frequency for this movie
    return total_frequency / director_frequency["Director"].size

# Apply the function to create the new 'directors_freq' column
df['directors_freq'] = df['Directors'].apply(calculate_directors_freq)

# Display a sample of the DataFrame with the new column
display(df[['Title', 'Directors', 'directors_freq']].sample(n=5))
# Out:
#                             Title                 Directors  directors_freq
# 4895                   Mecanismul               David Mamet        0.001887
# 9656                   Contracted              Eric England        0.000236
# 1256  Scream 4: Coșmarul continuă                Wes Craven        0.004010
# 675               Kung Fu Panda 2       Jennifer Yuh Nelson        0.000472
# 6857                Shanghai Kiss  Kern Konwiser, David Ren        0.000472

# %%
# Initialize an empty list to store all individual writers
all_writers = []

# Iterate through the 'Writers' column
for writers_list in df['Writers']:
    if pd.isna(writers_list):
        continue
    # Split the string by comma and strip whitespace from each name
    writers = [w.strip() for w in writers_list.split(',')]
    all_writers.extend(writers)

# Create a pandas Series from the list of all writers and count their frequencies
writer_frequency = pd.Series(all_writers).value_counts().reset_index()
writer_frequency.columns = ['Writer', 'Frequency']

# Display the new DataFrame with writer frequencies
display(writer_frequency)
display(writer_frequency["Writer"].size)
writer_frequency.to_csv('writer_frequency.csv', index=False)
# Out:
#                     Writer  Frequency
# 0              Woody Allen         49
# 1               Luc Besson         40
# 2             Stephen King         40
# 3      William Shakespeare         31
# 4              John Hughes         29
# ...                    ...        ...
# 10547    Manu Rishi Chadha          1
# 10548      Karl Vollmöller          1
# 10549       Carl Zuckmayer          1
# 10550        Heinrich Mann          1
# 10551     Takashi Yamazaki          1
#
# [10552 rows x 2 columns]
# 10552

# %%
writer_freq_dict = writer_frequency.set_index('Writer')['Frequency'].to_dict()

def calculate_writers_freq(writers_str):
    if pd.isna(writers_str):
        return None

    individual_writers = [w.strip() for w in writers_str.split(',')]
    total_frequency = 0

    for writer in individual_writers:
        total_frequency += writer_freq_dict.get(writer, 0) # Get frequency, default to 0 if not found

    # Calculate the average frequency for this movie
    return total_frequency / writer_frequency["Writer"].size

# Apply the function to create the new 'writers_freq' column
df['writers_freq'] = df['Writers'].apply(calculate_writers_freq)

# Display a sample of the DataFrame with the new column
display(df[['Title', 'Writers', 'writers_freq']].sample(n=5))
# Out:
#                                                   Title  \
# 3449                                         The Hunter
# 753                               Marele maestru Ip Man
# 6518                Howling II: Stirba - Werewolf Bitch
# 7643  Those Magnificent Men in Their Flying Machines...
# 7086                                  Ivan cel Groaznic
#
#                                           Writers  writers_freq
# 3449  Alice Addison, Wain Fimeri, Daniel Nettheim      0.000284
# 753                     Edmond Wong, Tai-Lee Chan      0.000569
# 6518                  Gary Brandner, Robert Sarno      0.000284
# 7643                     Jack Davies, Ken Annakin      0.000190
# 7086                            Sergei Eisenstein      0.000474

# %%
# Initialize an empty list to store all individual stars
all_stars = []

# Iterate through the 'Stars' column
for stars_list in df['Stars']:
    if pd.isna(stars_list):
        continue
    # Split the string by comma and strip whitespace from each name
    stars = [s.strip() for s in stars_list.split(',')]
    all_stars.extend(stars)

# Create a pandas Series from the list of all stars and count their frequencies
star_frequency = pd.Series(all_stars).value_counts().reset_index()
star_frequency.columns = ['Star', 'Frequency']

# Display the new DataFrame with star frequencies
display(star_frequency)
display(star_frequency["Star"].size)
star_frequency.to_csv('star_frequency.csv', index=False)
# Out:
#                     Star  Frequency
# 0         Robert De Niro         77
# 1      Samuel L. Jackson         69
# 2           Bruce Willis         62
# 3         Morgan Freeman         58
# 4           Nicolas Cage         57
# ...                  ...        ...
# 43947    Toralv Maurstad          1
# 43948   Rolf Just Nilsen          1
# 43949        Helge Reiss          1
# 43950       Frank Robert          1
# 43951      Kari Simonsen          1
#
# [43952 rows x 2 columns]
# 43952
# Warning: total number of rows (43952) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
star_freq_dict = star_frequency.set_index('Star')['Frequency'].to_dict()

def calculate_stars_freq(stars_str):
    if pd.isna(stars_str):
        return None

    individual_stars = [s.strip() for s in stars_str.split(',')]
    total_frequency = 0

    for star in individual_stars:
        total_frequency += star_freq_dict.get(star, 0) # Get frequency, default to 0 if not found

    # Calculate the average frequency for this movie
    return total_frequency / star_frequency["Star"].size

# Apply the function to create the new 'stars_freq' column
df['stars_freq'] = df['Stars'].apply(calculate_stars_freq)

# Display a sample of the DataFrame with the new column
display(df[['Title', 'Stars', 'stars_freq']].sample(n=5))
# Out:
#                                 Title  \
# 7668  Stan și Bran: Departe spre vest
# 162                     În sălbăticie
# 6562                    Staten Island
# 3796                    Doc Hollywood
# 9638                    Fata din vale
#
#                                                   Stars  stars_freq
# 7668  Stan Laurel, Oliver Hardy, Sharon Lynn, James ...    0.000364
# 162   Emile Hirsch, Marcia Gay Harden, William Hurt,...    0.004346
# 6562  Ethan Hawke, Vincent D'Onofrio, Seymour Cassel...    0.002161
# 3796  Michael J. Fox, Julie Warner, Barnard Hughes, ...    0.002776
# 9638  Nicolas Cage, Deborah Foreman, Elizabeth Daily...    0.002139

# %%
# Initialize an empty list to store all individual genres
all_genres = []

# Iterate through the 'Genres' column
for genres_list in df['Genres']:
    if pd.isna(genres_list):
        continue
    # Split the string by comma and strip whitespace from each name
    genres = [g.strip() for g in genres_list.split(',')]
    all_genres.extend(genres)

# Create a pandas Series from the list of all genres and count their frequencies
genre_frequency = pd.Series(all_genres).value_counts().reset_index()
genre_frequency.columns = ['Genre', 'Frequency']

# Display the new DataFrame with genre frequencies
display(genre_frequency)
display(genre_frequency["Genre"].size)
genre_frequency.to_csv('genre_frequency.csv', index=False)
# Out:
#                  Genre  Frequency
# 0                Drama       5792
# 1               Comedy       3773
# 2             Thriller       2915
# 3              Romance       2461
# 4               Action       2133
# ..                 ...        ...
# 198           Stand-Up          1
# 199        Documentary          1
# 200  Music Documentary          1
# 201            Punjabi          1
# 202             Isekai          1
#
# [203 rows x 2 columns]
# 203

# %%
genre_freq_dict = genre_frequency.set_index('Genre')['Frequency'].to_dict()

def calculate_genres_freq(genres_str):
    if pd.isna(genres_str):
        return None

    individual_genres = [g.strip() for g in genres_str.split(',')]
    total_frequency = 0

    for genre in individual_genres:
        total_frequency += genre_freq_dict.get(genre, 0) # Get frequency, default to 0 if not found

    # Calculate the average frequency for this movie
    return total_frequency / genre_frequency["Genre"].size

# Apply the function to create the new 'genres_freq' column
df['genres_freq'] = df['Genres'].apply(calculate_genres_freq)

# Display a sample of the DataFrame with the new column
display(df[['Title', 'Genres', 'genres_freq']].sample(n=5))
# Out:
#                Title                                             Genres  \
# 8952         Branded  Conspiracy Thriller, Drama, Fantasy, Sci-Fi, T...
# 5106  My Blue Heaven                        Buddy Comedy, Comedy, Crime
# 6550       Arabesque  Screwball Comedy, Spy, Action, Adventure, Come...
# 9745          Tarzan  Jungle Adventure, Adventure, Animation, Drama,...
# 4764     Tillsammans                    Swedish, Comedy, Drama, Romance
#
#       genres_freq
# 8952    52.975369
# 5106    29.970443
# 6550   108.699507
# 9745    41.807882
# 4764    59.502463

# %%
display(df.head())
# Out:
#                         Title  Rating Runtime          Directors  \
# 0       Închisoarea îngerilor     9.3  2h 22m     Frank Darabont
# 1             Cavalerul negru     9.1  2h 32m  Christopher Nolan
# 2                   Începutul     8.8  2h 28m  Christopher Nolan
# 3  Fight Club - Sala de lupte     8.8  2h 19m      David Fincher
# 4                Pulp Fiction     8.8  2h 34m  Quentin Tarantino
#
#                                              Writers  \
# 0                       Stephen King, Frank Darabont
# 1  Jonathan Nolan, Christopher Nolan, David S. Goyer
# 2                                  Christopher Nolan
# 3                          Chuck Palahniuk, Jim Uhls
# 4                     Quentin Tarantino, Roger Avary
#
#                                                Stars  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 3  Edward Norton, Brad Pitt, Meat Loaf, Zach Gren...
# 4  Tim Roth, Amanda Plummer, Laura Lovelace, John...
#
#                                               Genres  Popularity       Budget  \
# 0            Epic, Period Drama, Prison Drama, Drama        55.0   25000000.0
# 1  Action Epic, Epic, Psychological Drama, Psycho...        92.0  185000000.0
# 2  Action Epic, Adventure Epic, Epic, Psychologic...        84.0  160000000.0
# 3  Dark Comedy, Psychological Drama, Psychologica...       148.0   63000000.0
# 4    Dark Comedy, Drug Crime, Gangster, Crime, Drama       141.0    8000000.0
#
#    Gross Worldwide                                    URL  Runtime (minutes)  \
# 0     2.933403e+07  https://www.imdb.com/title/tt0111161/                142
# 1     1.009243e+09  https://www.imdb.com/title/tt0468569/                152
# 2     8.397865e+08  https://www.imdb.com/title/tt1375666/                148
# 3     1.013210e+08  https://www.imdb.com/title/tt0137523/                139
# 4     2.139288e+08  https://www.imdb.com/title/tt0110912/                154
#
#          ROI  directors_freq  writers_freq  stars_freq  genres_freq
# 0   1.173361        0.000944      0.004265    0.004004    33.359606
# 1   5.455367        0.002123      0.002559    0.005825    73.546798
# 2   5.248665        0.002123      0.000853    0.003618    41.704433
# 3   1.608270        0.002359      0.000379    0.002457    63.610837
# 4  26.741095        0.002595      0.001801    0.005734    45.305419

# %%
new_df = df.drop(columns=["Title","Runtime","Directors","Writers","Stars","Genres","Budget","Gross Worldwide","URL"])

# %%
import numpy as np

new_df.to_csv('freq_encoding_final.csv', index=False)



new_df["ROI"] = np.log1p(new_df["ROI"])
display(new_df.head())
# Out:
#    Rating  Popularity  Runtime (minutes)       ROI  directors_freq  \
# 0     9.3        55.0                142  0.776275        0.000944
# 1     9.1        92.0                152  1.864912        0.002123
# 2     8.8        84.0                148  1.832368        0.002123
# 3     8.8       148.0                139  0.958687        0.002359
# 4     8.8       141.0                154  3.322915        0.002595
#
#    writers_freq  stars_freq  genres_freq
# 0      0.004265    0.004004    33.359606
# 1      0.002559    0.005825    73.546798
# 2      0.000853    0.003618    41.704433
# 3      0.000379    0.002457    63.610837
# 4      0.001801    0.005734    45.305419

# %% [markdown]
# # Task
# Build a neural network model to predict 'ROI' using the features in the `new_df` DataFrame.

# %% [markdown]
# ## Prepare Data for Neural Network
#
# ### Subtask:
# Separate features (X) and target (y), handle any missing values, scale the features, and split the data into training and testing sets.

# %% [markdown]
# **Reasoning**:
# The first step is to separate the target variable 'ROI' into `y` and the remaining columns of `new_df` into `X`. Then, I will handle any missing values in `X` and `y` by filling them with the mean of their respective columns.

# %%
y = new_df['ROI']
X = new_df.drop('ROI', axis=1)

# Identify and fill missing values in X
for col in X.columns:
    if X[col].isnull().sum() > 0:
        X[col] = X[col].fillna(X[col].mean())

# Identify and fill missing values in y
if y.isnull().sum() > 0:
    y = y.fillna(y.mean())

print("Missing values in X after handling:\n", X.isnull().sum().sum())
print("Missing values in y after handling:\n", y.isnull().sum())
# Out:
# Missing values in X after handling:
#  0
# Missing values in y after handling:
#  0

# %% [markdown]
# **Reasoning**:
# I will now scale the features in `X` using `StandardScaler` and then split the scaled features `X_scaled` and the target `y` into training and testing sets using `train_test_split`.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (7798, 7)
# Shape of X_test: (1950, 7)
# Shape of y_train: (7798,)
# Shape of y_test: (1950,)

# %% [markdown]
# ## Define and Compile the Neural Network Model
#
# ### Subtask:
# Create a TensorFlow/Keras sequential model with appropriate layers, activation functions, and compile it with an optimizer and loss function suitable for regression.

# %% [markdown]
# **Reasoning**:
# I will import the necessary Keras modules, define a sequential neural network model with input, hidden, and output layers, and then compile it with an appropriate optimizer, loss function, and metrics for regression.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 1. Initialize a Sequential model
model = Sequential()

# 2. Add the input layer
# input_dim should be the number of features in X_train
model.add(Dense(128, input_dim=X_train.shape[1], activation='tanh'))

# 3. Add one or more hidden layers
model.add(Dense(32, activation='tanh'))
# model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(8, activation='tanh'))

# 4. Add the output layer for regression (1 unit, no activation)
model.add(Dense(1))

# 5. Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Display the model summary
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,825 (22.75 KB)
#  Trainable params: 5,825 (22.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from sklearn.metrics import r2_score

history = model.fit(
    X_train,
    y_train,
    epochs=100,  # You can adjust the number of epochs
    batch_size=128, # You can adjust the batch size
    validation_split=0.2, # Use a portion of training data for validation
    verbose=1
)

# Evaluate the model on the test data
loss, mae = model.evaluate(X_test, y_test, verbose=0)

# Get predictions on the test set
y_pred = model.predict(X_test)

# Calculate R2 score
r2 = r2_score(y_test, y_pred)

print(f"Test Loss (Mean Squared Error): {loss:.4f}")
print(f"Test Mean Absolute Error: {mae:.4f}")
print(f"Test R2 Score: {r2:.4f}")
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.9989 - mean_absolute_error: 0.6741 - val_loss: 0.5559 - val_mean_absolute_error: 0.5622
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6271 - mean_absolute_error: 0.5656 - val_loss: 0.5572 - val_mean_absolute_error: 0.5651
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6255 - mean_absolute_error: 0.5592 - val_loss: 0.5179 - val_mean_absolute_error: 0.5442
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5657 - mean_absolute_error: 0.5402 - val_loss: 0.5244 - val_mean_absolute_error: 0.5570
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5852 - mean_absolute_error: 0.5482 - val_loss: 0.5010 - val_mean_absolute_error: 0.5400
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5384 - mean_absolute_error: 0.5284 - val_loss: 0.4995 - val_mean_absolute_error: 0.5302
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5872 - mean_absolute_error: 0.5390 - val_loss: 0.5034 - val_mean_absolute_error: 0.5302
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5173 - mean_absolute_error: 0.5255 - val_loss: 0.4929 - val_mean_absolute_error: 0.5284
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5260 - mean_absolute_error: 0.5304 - val_loss: 0.4886 - val_mean_absolute_error: 0.5297
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5191 - mean_absolute_error: 0.5193 - val_loss: 0.4865 - val_mean_absolute_error: 0.5307
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5495 - mean_absolute_error: 0.5315 - val_loss: 0.4911 - val_mean_absolute_error: 0.5185
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5240 - mean_absolute_error: 0.5208 - val_loss: 0.4781 - val_mean_absolute_error: 0.5066
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6091 - mean_absolute_error: 0.5446 - val_loss: 0.4806 - val_mean_absolute_error: 0.5106
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5163 - mean_absolute_error: 0.5179 - val_loss: 0.4810 - val_mean_absolute_error: 0.5182
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5360 - mean_absolute_error: 0.5259 - val_loss: 0.4880 - val_mean_absolute_error: 0.5172
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5242 - mean_absolute_error: 0.5186 - val_loss: 0.4806 - val_mean_absolute_error: 0.5249
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5411 - mean_absolute_error: 0.5248 - val_loss: 0.4875 - val_mean_absolute_error: 0.5103
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5720 - mean_absolute_error: 0.5161 - val_loss: 0.4783 - val_mean_absolute_error: 0.5146
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5547 - mean_absolute_error: 0.5259 - val_loss: 0.4850 - val_mean_absolute_error: 0.5224
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5331 - mean_absolute_error: 0.5231 - val_loss: 0.4832 - val_mean_absolute_error: 0.5145
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5767 - mean_absolute_error: 0.5324 - val_loss: 0.4807 - val_mean_absolute_error: 0.5099
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4977 - mean_absolute_error: 0.5071 - val_loss: 0.4942 - val_mean_absolute_error: 0.5367
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5351 - mean_absolute_error: 0.5272 - val_loss: 0.4844 - val_mean_absolute_error: 0.5169
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5617 - mean_absolute_error: 0.5293 - val_loss: 0.4805 - val_mean_absolute_error: 0.5142
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5359 - mean_absolute_error: 0.5162 - val_loss: 0.4763 - val_mean_absolute_error: 0.5132
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5157 - mean_absolute_error: 0.5191 - val_loss: 0.4784 - val_mean_absolute_error: 0.5131
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5641 - mean_absolute_error: 0.5238 - val_loss: 0.4827 - val_mean_absolute_error: 0.5220
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4867 - mean_absolute_error: 0.5072 - val_loss: 0.4867 - val_mean_absolute_error: 0.5310
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5300 - mean_absolute_error: 0.5185 - val_loss: 0.4866 - val_mean_absolute_error: 0.5201
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5074 - mean_absolute_error: 0.5143 - val_loss: 0.4876 - val_mean_absolute_error: 0.5210
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5030 - mean_absolute_error: 0.5131 - val_loss: 0.4841 - val_mean_absolute_error: 0.5153
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5324 - mean_absolute_error: 0.5082 - val_loss: 0.4874 - val_mean_absolute_error: 0.5217
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5425 - mean_absolute_error: 0.5210 - val_loss: 0.4842 - val_mean_absolute_error: 0.5054
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5264 - mean_absolute_error: 0.5106 - val_loss: 0.4789 - val_mean_absolute_error: 0.5084
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5786 - mean_absolute_error: 0.5275 - val_loss: 0.4856 - val_mean_absolute_error: 0.5184
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5387 - mean_absolute_error: 0.5237 - val_loss: 0.4803 - val_mean_absolute_error: 0.5161
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5406 - mean_absolute_error: 0.5253 - val_loss: 0.4791 - val_mean_absolute_error: 0.5122
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5121 - mean_absolute_error: 0.5130 - val_loss: 0.4801 - val_mean_absolute_error: 0.5152
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5151 - mean_absolute_error: 0.5123 - val_loss: 0.4783 - val_mean_absolute_error: 0.5119
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5356 - mean_absolute_error: 0.5152 - val_loss: 0.4818 - val_mean_absolute_error: 0.5104
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5117 - mean_absolute_error: 0.5041 - val_loss: 0.4818 - val_mean_absolute_error: 0.5176
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5086 - mean_absolute_error: 0.5133 - val_loss: 0.4820 - val_mean_absolute_error: 0.5086
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5076 - mean_absolute_error: 0.5081 - val_loss: 0.4792 - val_mean_absolute_error: 0.5257
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5500 - mean_absolute_error: 0.5209 - val_loss: 0.4763 - val_mean_absolute_error: 0.5062
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5000 - mean_absolute_error: 0.5165 - val_loss: 0.4807 - val_mean_absolute_error: 0.5260
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5097 - mean_absolute_error: 0.5094 - val_loss: 0.4851 - val_mean_absolute_error: 0.5238
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5110 - mean_absolute_error: 0.5154 - val_loss: 0.4863 - val_mean_absolute_error: 0.5253
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5267 - mean_absolute_error: 0.5052 - val_loss: 0.4867 - val_mean_absolute_error: 0.5210
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5032 - mean_absolute_error: 0.4967 - val_loss: 0.4778 - val_mean_absolute_error: 0.5109
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5424 - mean_absolute_error: 0.5105 - val_loss: 0.4801 - val_mean_absolute_error: 0.5202
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4960 - mean_absolute_error: 0.4995 - val_loss: 0.4771 - val_mean_absolute_error: 0.5153
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5116 - mean_absolute_error: 0.5031 - val_loss: 0.4808 - val_mean_absolute_error: 0.5115
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5107 - mean_absolute_error: 0.5135 - val_loss: 0.4785 - val_mean_absolute_error: 0.5216
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5202 - mean_absolute_error: 0.5137 - val_loss: 0.4817 - val_mean_absolute_error: 0.5051
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5314 - mean_absolute_error: 0.5042 - val_loss: 0.4748 - val_mean_absolute_error: 0.5103
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5014 - mean_absolute_error: 0.5011 - val_loss: 0.4824 - val_mean_absolute_error: 0.5201
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5261 - mean_absolute_error: 0.5168 - val_loss: 0.4778 - val_mean_absolute_error: 0.5105
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4979 - mean_absolute_error: 0.4969 - val_loss: 0.4862 - val_mean_absolute_error: 0.5318
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5653 - mean_absolute_error: 0.5251 - val_loss: 0.4798 - val_mean_absolute_error: 0.5115
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4854 - mean_absolute_error: 0.5007 - val_loss: 0.4808 - val_mean_absolute_error: 0.5088
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5265 - mean_absolute_error: 0.5111 - val_loss: 0.4802 - val_mean_absolute_error: 0.5077
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5238 - mean_absolute_error: 0.4960 - val_loss: 0.4798 - val_mean_absolute_error: 0.5134
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5366 - mean_absolute_error: 0.5119 - val_loss: 0.4805 - val_mean_absolute_error: 0.5045
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5004 - mean_absolute_error: 0.4999 - val_loss: 0.4799 - val_mean_absolute_error: 0.5092
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5326 - mean_absolute_error: 0.5086 - val_loss: 0.4778 - val_mean_absolute_error: 0.5053
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4889 - mean_absolute_error: 0.5012 - val_loss: 0.4794 - val_mean_absolute_error: 0.5137
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5434 - mean_absolute_error: 0.4984 - val_loss: 0.4936 - val_mean_absolute_error: 0.5365
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5212 - mean_absolute_error: 0.5029 - val_loss: 0.4778 - val_mean_absolute_error: 0.5096
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4768 - mean_absolute_error: 0.4993 - val_loss: 0.4773 - val_mean_absolute_error: 0.5123
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4492 - mean_absolute_error: 0.4821 - val_loss: 0.4830 - val_mean_absolute_error: 0.5186
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4933 - mean_absolute_error: 0.5003 - val_loss: 0.4794 - val_mean_absolute_error: 0.5093
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5736 - mean_absolute_error: 0.5055 - val_loss: 0.4846 - val_mean_absolute_error: 0.5179
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4559 - mean_absolute_error: 0.4801 - val_loss: 0.4833 - val_mean_absolute_error: 0.5192
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4966 - mean_absolute_error: 0.4976 - val_loss: 0.4844 - val_mean_absolute_error: 0.5143
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4725 - mean_absolute_error: 0.4940 - val_loss: 0.4858 - val_mean_absolute_error: 0.5250
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5298 - mean_absolute_error: 0.5076 - val_loss: 0.4879 - val_mean_absolute_error: 0.5144
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5764 - mean_absolute_error: 0.5090 - val_loss: 0.4808 - val_mean_absolute_error: 0.5117
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4899 - mean_absolute_error: 0.4952 - val_loss: 0.4847 - val_mean_absolute_error: 0.5216
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4772 - mean_absolute_error: 0.4948 - val_loss: 0.4833 - val_mean_absolute_error: 0.5230
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4808 - mean_absolute_error: 0.4952 - val_loss: 0.4844 - val_mean_absolute_error: 0.5108
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4772 - mean_absolute_error: 0.4840 - val_loss: 0.4889 - val_mean_absolute_error: 0.5225
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4638 - mean_absolute_error: 0.4912 - val_loss: 0.4879 - val_mean_absolute_error: 0.5189
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4647 - mean_absolute_error: 0.4893 - val_loss: 0.4837 - val_mean_absolute_error: 0.5136
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4917 - mean_absolute_error: 0.5036 - val_loss: 0.4841 - val_mean_absolute_error: 0.5103
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4940 - mean_absolute_error: 0.4989 - val_loss: 0.4861 - val_mean_absolute_error: 0.5103
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4924 - mean_absolute_error: 0.4925 - val_loss: 0.4916 - val_mean_absolute_error: 0.5178
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5297 - mean_absolute_error: 0.5116 - val_loss: 0.4915 - val_mean_absolute_error: 0.5208
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5304 - mean_absolute_error: 0.5079 - val_loss: 0.4881 - val_mean_absolute_error: 0.5232
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4860 - mean_absolute_error: 0.4879 - val_loss: 0.4887 - val_mean_absolute_error: 0.5125
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4615 - mean_absolute_error: 0.4882 - val_loss: 0.4984 - val_mean_absolute_error: 0.5326
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4833 - mean_absolute_error: 0.4977 - val_loss: 0.4911 - val_mean_absolute_error: 0.5233
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4900 - mean_absolute_error: 0.4942 - val_loss: 0.4921 - val_mean_absolute_error: 0.5223
# Epoch 93/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4767 - mean_absolute_error: 0.4975 - val_loss: 0.4921 - val_mean_absolute_error: 0.5317
# Epoch 94/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4943 - mean_absolute_error: 0.4994 - val_loss: 0.4914 - val_mean_absolute_error: 0.5131
# Epoch 95/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5191 - mean_absolute_error: 0.4968 - val_loss: 0.4895 - val_mean_absolute_error: 0.5200
# Epoch 96/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4573 - mean_absolute_error: 0.4916 - val_loss: 0.4911 - val_mean_absolute_error: 0.5096
# Epoch 97/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4752 - mean_absolute_error: 0.4853 - val_loss: 0.4874 - val_mean_absolute_error: 0.5107
# Epoch 98/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4854 - mean_absolute_error: 0.4868 - val_loss: 0.4926 - val_mean_absolute_error: 0.5252
# Epoch 99/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5685 - mean_absolute_error: 0.4982 - val_loss: 0.4866 - val_mean_absolute_error: 0.5121
# Epoch 100/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4890 - mean_absolute_error: 0.4900 - val_loss: 0.4971 - val_mean_absolute_error: 0.5219
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Loss (Mean Squared Error): 0.6250
# Test Mean Absolute Error: 0.5544
# Test R2 Score: 0.1725
